# %% [markdown]
# # **Airbnb Booking Analysis**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Objective of this capstone is to do EDA on the given dataset and find out the insights from it.
# In this dataset we are provided with 16 features and around 49k data instances.
# Now the basic thing to start with is the exploring the features and finding out the meaningful insights from it.
# I started with doing NA value handling, univariate analysis, multivariate analysis and conclusion.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Hasnain-Rizvi/Hasnain-EDA-AirBnb.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **1. Who  has Most Listing in NYC**
#
# **2. Listing in Each Neighbourhood Groups**
#
# **3. Expensive Neighbourhood Group (Location of NYC)**
#
# **4. Most Listing in Each Room**
#
# **5. Most Listed Neighbourhood (Area of Location in NYC) (ex : Kensigton, Midtown, Harlem etc..)**
#
# **6. How Price is correspond to minimum nights**
#
# **7. Number of Reviews**
#
# **8. Most Desnsed Places According to Latitude and Longitude**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To provide the facility to the community through easy of service of hotel room and appartments.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/EDA/Airbnb NYC 2019.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
plt.rcParams['figure.figsize']=(10,6)
sns.heatmap(df.isna().transpose(),cmap="YlGnBu",cbar_kws={'label': 'Missing Data'})

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Dataset provided us is about AirBnb website which works on the hotels ,room and appartment facility and we have to solve the problem which company face with respect to thier price ,location, facility, area and many more aspects, wehave 49k rows and 16 columns to give the solution.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **df** : main dataset which is read from CSV
#
# **host_id_max** : host_id maximum counts
#
# **df_host_id** : DataFrame for host_id
#
# **plot_1** : Visualization of highest listings
#
# **total_neighbourhood_group** : neighbourhood_group column counts
#
# **grouping_neighbour_group** : grouping of neighbourhood_group column
#
# **expensive_neighbour_group** : price of neighbourhood_group column
#
# **plot_4** : Expensive neighbouring group
#
# **minimum_nights_var** :varaible of minimum_nights
#
# **var_room_type** : room_type counts
#
# **dframe_room_type** : DataFrame of room_type
#
# **stat_max_room_list** :Grouping of neighbourhood_group and room_type column
#
# **plot_5** : visualization of Most Listing for Each Room
#
# **max_value_neigh** : neighbourhood value count
#
# **get_max_value_neigh** : sorting index of neighbourhood
#
# **plt_6** : visualization of Most Listing for neighbourhood
#
# **plot_7** : visualization for Most Densed Places According to Latitude and Longitude

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for num in df.columns.tolist():
  print("The Number of unique values in ",num,"is",df[num].nunique(),".")
# Out:
# The Number of unique values in  id is 48895 .
# The Number of unique values in  name is 47905 .
# The Number of unique values in  host_id is 37457 .
# The Number of unique values in  host_name is 11452 .
# The Number of unique values in  neighbourhood_group is 5 .
# The Number of unique values in  neighbourhood is 221 .
# The Number of unique values in  latitude is 19048 .
# The Number of unique values in  longitude is 14718 .
# The Number of unique values in  room_type is 3 .
# The Number of unique values in  price is 674 .
# The Number of unique values in  minimum_nights is 109 .
# The Number of unique values in  number_of_reviews is 394 .
# The Number of unique values in  last_review is 1764 .
# The Number of unique values in  reviews_per_month is 937 .
# The Number of unique values in  calculated_host_listings_count is 47 .
# The Number of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Droping the columns 'name' , 'host_name' and 'last_review' 
df.drop(['name','host_name','last_review'],axis=1,inplace=True)

# %%
# Now Let's see how df looks now
df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# * As we wanted the 'reviews_per_month' so thats why its only null values is showing of 'reviews_per_month'
#
# * Lets fill it with zeros

# %%
# Changing null values to Zero
df.fillna({'reviews_per_month' : 0},inplace=True)

# And lets see df again
df.isnull().sum()
# Out:
# id                                0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# *  Now there is no null values in our database

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         7.029962          23.274466           1.090910
# std         20.510550          44.550582           1.597283
# ...

# %% [markdown]
# * As we observed that the 'price' is 0 in (min) ,which is not acceptable in real world scenario.
#
# * And the 'minimum_nights' is 1250 in (max), which is too high in real world scenario
#
# * Let's Figure it out....

# %%
# look over to price == 0
df[df['price']==0]
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 23161  18750597    8993084            Brooklyn  Bedford-Stuyvesant  40.69023
# 25433  20333471  131697576               Bronx     East Morrisania  40.83296
# 25634  20523843   15787004            Brooklyn            Bushwick  40.69467
# 25753  20608117    1641537            Brooklyn          Greenpoint  40.72462
# 25778  20624541   10132166            Brooklyn        Williamsburg  40.70838
# 25794  20639628   86327101            Brooklyn  Bedford-Stuyvesant  40.68173
# 25795  20639792   86327101            Brooklyn  Bedford-Stuyvesant  40.68279
# 25796  20639914   86327101            Brooklyn  Bedford-Stuyvesant  40.68258
# 26259  20933849   13709292           Manhattan         Murray Hill  40.75091
# 26841  21291569  101970559            Brooklyn            Bushwick  40.69211
# 26866  21304320  101970559            Brooklyn            Bushwick  40.69166
#
# ...

# %%
# Lets replace of 0 with 120
df[df['price']==0] = df[df['price']==120]

# %%
# Now let us check it
df[df['price']==0]
# Out:
# Empty DataFrame
# Columns: [id, host_id, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# * Now we have no Zero values in 'price'
#
# * Now lets see the 'minimum_night' to get it corrected
#
# * Lets assume that someone can pay full rent of 1 year (which 365 days) so lets convert max() of 'minimum_night' to 365

# %%
# converting max() value of minimum_night to 365
df[df['minimum_nights'] >=365] = df[df['minimum_nights'] ==365]

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.887000e+04  4.887000e+04  48870.000000  48870.000000  48870.000000
# mean   1.901848e+07  6.762985e+07     40.728952    -73.952172    152.759402
# std    1.098393e+07  7.862005e+07      0.054534      0.046163    240.199363
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.472371e+06  7.821708e+06     40.690092    -73.983080     69.000000
# 50%    1.967676e+07  3.080150e+07     40.723080    -73.955690    106.000000
# 75%    2.915342e+07  1.074344e+08     40.763127    -73.936280    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48870.000000       48870.000000       48870.000000
# mean         6.840311          23.277143           1.091070
# std         16.453077          44.556389           1.597354
# ...

# %% [markdown]
# * Data is Cleaned, Now we can go ahead of our Analysis

# %%
# Write your code to make your dataset analysis ready.
# df = variable of csv dataset
host_id_max = df['host_id'].value_counts().head(10)
host_id_max
# Out:
# 219517861.0    327
# 107434423.0    232
# 30283594.0     121
# 137358866.0    103
# 12243051.0      96
# 16098958.0      96
# 61391963.0      91
# 22541573.0      87
# 200380610.0     65
# 1475015.0       52
# Name: host_id, dtype: int64

# %% [markdown]
# * As the highest host_id is 327 which means the highest listing

# %%
# Creating a Data frame for Further Analysis
df_host_id = pd.DataFrame(data=host_id_max)
df_host_id.reset_index(inplace=True)
df_host_id.rename(columns = {'index' : 'Host_id','host_id' : 'Listing_count'},inplace=True)
df_host_id
# Out:
#        Host_id  Listing_count
# 0  219517861.0            327
# 1  107434423.0            232
# 2   30283594.0            121
# 3  137358866.0            103
# 4   12243051.0             96
# 5   16098958.0             96
# 6   61391963.0             91
# 7   22541573.0             87
# 8  200380610.0             65
# 9    1475015.0             52

# %%
# Grouping of neighbourhood_group for plotting
total_neighbourhood_group= df['neighbourhood_group'].value_counts()
total_neighbourhood_group
# Out:
# Manhattan        21654
# Brooklyn         20089
# Queens            5664
# Bronx             1090
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# Creat a variable for grouping the neihbourhood_group for prices and expenses
grouping_neighbour_group = df.groupby('neighbourhood_group')
grouping_neighbour_group.first()
# Out:
#                           id   host_id     neighbourhood  latitude  longitude  \
# neighbourhood_group
# Bronx                44096.0  190409.0        Highbridge  40.83232  -73.93184
# Brooklyn              2539.0    2787.0        Kensington  40.64749  -73.97237
# Manhattan             2595.0    2845.0           Midtown  40.75362  -73.98377
# Queens               12937.0   50124.0  Long Island City  40.74771  -73.94740
# Staten Island        42882.0  185978.0        St. George  40.64524  -74.08088
#
#                            room_type  price  minimum_nights  \
# neighbourhood_group
# Bronx                   Private room   40.0             1.0
# Brooklyn                Private room  149.0             1.0
# Manhattan            Entire home/apt  225.0             1.0
# Queens                  Private room  130.0             3.0
# Staten Island           Private room   70.0             2.0
#
#                      number_of_reviews  reviews_per_month  \
# neighbourhood_group
# ...

# %%
# Now as we want expensive group se have to select only  'price'  columns  
expensive_neighbour_group = grouping_neighbour_group['price'].describe()
expensive_neighbour_group
# Out:
#                        count        mean         std   min   25%    50%  \
# neighbourhood_group
# Bronx                 1090.0   87.577064  106.725371  10.0  45.0   65.0
# Brooklyn             20089.0  124.452238  186.922112  10.0  60.0   90.0
# Manhattan            21654.0  196.888011  291.421157  10.0  95.0  150.0
# Queens                5664.0   99.493997  167.125802  10.0  50.0   75.0
# Staten Island          373.0  114.812332  277.620403  13.0  50.0   75.0
#
#                        75%      max
# neighbourhood_group
# Bronx                 99.0   2500.0
# Brooklyn             150.0  10000.0
# Manhattan            220.0  10000.0
# Queens               110.0  10000.0
# Staten Island        110.0   5000.0

# %%
# price vs minimum_nights
minimum_nights_var='minimum_nights'
data=pd.concat([df['price'],df[minimum_nights_var]],axis=1)

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
var_room_type = df['room_type'].value_counts()
var_room_type
# Out:
# Entire home/apt    25398
# Private room       22315
# Shared room         1157
# Name: room_type, dtype: int64

# %%
dframe_room_type = pd.DataFrame(data=var_room_type)
dframe_room_type.reset_index(inplace=True)
dframe_room_type.rename(columns = {'index' : 'Rooms','room_type' : 'Counts'},inplace=True)
dframe_room_type
# Out:
#              Rooms  Counts
# 0  Entire home/apt   25398
# 1     Private room   22315
# 2      Shared room    1157

# %%
# heatmap for pair
col_after_excluding_o = set(df.columns) - {'latitude', 'longitude', 'id', 'host_id'}
dist_col_list_o = df[col_after_excluding].describe().columns.tolist()

# %%
stat_max_room_list = df.groupby(['neighbourhood_group','room_type'])['host_id'].count().unstack()
stat_max_room_list
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           651           60
# Brooklyn                        9556         10122          411
# Manhattan                      13193          7982          479
# Queens                          2094          3372          198
# Staten Island                    176           188            9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48870 non-null  float64
#  1   host_id                         48870 non-null  float64
#  2   neighbourhood_group             48870 non-null  object
#  3   neighbourhood                   48870 non-null  object
#  4   latitude                        48870 non-null  float64
#  5   longitude                       48870 non-null  float64
#  6   room_type                       48870 non-null  object
#  7   price                           48870 non-null  float64
#  8   minimum_nights                  48870 non-null  float64
#  9   number_of_reviews               48870 non-null  float64
#  10  reviews_per_month               48870 non-null  float64
#  11  calculated_host_listings_count  48870 non-null  float64
# ...

# %%
max_value_neigh = df['neighbourhood'].value_counts().head(15)
max_value_neigh
# Out:
# Williamsburg          3917
# Bedford-Stuyvesant    3709
# Harlem                2656
# Bushwick              2461
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1563
# Midtown               1544
# East Harlem           1117
# Greenpoint            1114
# Chelsea               1113
# Lower East Side        911
# Astoria                900
# Name: neighbourhood, dtype: int64

# %%
get_max_value_neigh =max_value_neigh.reset_index()
get_max_value_neigh
# Out:
#                  index  neighbourhood
# 0         Williamsburg           3917
# 1   Bedford-Stuyvesant           3709
# 2               Harlem           2656
# 3             Bushwick           2461
# 4      Upper West Side           1971
# 5       Hell's Kitchen           1958
# 6         East Village           1853
# 7      Upper East Side           1798
# 8        Crown Heights           1563
# 9              Midtown           1544
# 10         East Harlem           1117
# 11          Greenpoint           1114
# 12             Chelsea           1113
# 13     Lower East Side            911
# 14             Astoria            900

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Now After all manipulations on dataset we are preety sure about where our dataset is going,and where its lagging .
#
#
# *   First thing the data was need to be claned before we take it to the analysis part.
# *   We found some null values in it
# *   As above we seen in visulization graph there was four columns which had the null values but the most of the null values is from review_per_month and last_review
# *   so first we had to take it down of all the null values to the corresponding values
# *   After that the droping of not important columns
# *   Then after we made couple of DAtaFrames which we gonna need in ploting the graphs , whihc we gonna see in a while.
#
# *  Insights of the dataset is that the data was not that dirty to be cleaned , the values was preety nice and as far as the states we will gonna see it in our graph plotting.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# **1. Most Listing in NYC**

# %% [markdown]
# * **Using Seaborn Barplot**

# %%
# Chart - 1 visualization code
plot_1 = sns.barplot(x='Host_id',y='Listing_count',data=df_host_id)
plot_1.set_title('Most Listing in NYC')
plot_1.set_ylabel('Listing Counts')
plot_1.set_xlabel('Number of Host')
plot_1.set_xticklabels(plot_1.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, '1475015.0'),
#  Text(0, 0, '12243051.0'),
#  Text(0, 0, '16098958.0'),
#  Text(0, 0, '22541573.0'),
#  Text(0, 0, '30283594.0'),
#  Text(0, 0, '61391963.0'),
#  Text(0, 0, '107434423.0'),
#  Text(0, 0, '137358866.0'),
#  Text(0, 0, '200380610.0'),
#  Text(0, 0, '219517861.0')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Barplot is always easy to understand and plus advantage it contains all the data at one single graph

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * we can see that from graph the most listings is one owner which is highest locations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The property which having most number of hosting is from a one perticular owner which means most of properties have one owner it self,
#
# * the postive take away is more in this that if we promote the serivies to most proprt onwer then it will lead most of listings.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# **2. Listing in Each Neighbourhood Groups**

# %% [markdown]
# * Using matplotlib Line Plot

# %%
# Chart - 2 visualization code

plt.plot(total_neighbourhood_group)

plt.title('Listing in Each Neighbourhood')
plt.xlabel('Neighbourhood_group')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Less complex to understand, the visulization is preety clear with matplotlib lineplot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# According to the Anaysis Manhatten is favorates in listing which have highest listings and follwed by Brooklyn, Queen , Bronx and least Staten island respectively.
#
#
# *  Manhatten is more then 20000 listing which is highest in other neighbourhood groups
# *   followed by Brooklyn is near to 20000 listings as compare to other groups
# * Queen is more then 5000
# * Bronx is more then 1000
# * staten island is only 373 listings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Insights guided us that the aiming of positon is very importent role as we see in the graph that the Manhatten and Brooklyn is most listings becasue of its area of neighbourhood

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# *  **Using matplotlib Bar Plot**

# %%
# Chart - 3 visualization code

total_neighbourhood_group.plot(kind='bar',color='green')

plt.title('Listing in Each Neighbourhood')
plt.xlabel('Neighbourhood_group')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Second graph of above problem statements and its giving corresponding values with bar is preety easy understanding

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This is the second graph of the Highest listings that why the insight and nussiness grwoth statements same as above char - 2
#
#
# * Manhatten is more then 20000 listing which is highest in other neighbourhood groups
# * followed by Brooklyn is near to 20000 listings as compare to other groups
# * Queen is more then 5000
# * Bronx is more then 1000
# * staten island is only 373 listings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * This is the second graph of the Highest listings that why the insight and nussiness grwoth statements same as above char - 2

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# **3. Expensive Neighbourhood Group (Location of NYC)**

# %% [markdown]
# * **Using Seaborn Barplot**

# %%
# Chart - 4 visualization code

plot_4 = sns.barplot(y=expensive_neighbour_group['mean'],x=expensive_neighbour_group.index[0:5])

plot_4.set_title('Listing of Expensive Neighbourhood Group')
plot_4.set_ylabel('Mean Price')
plot_4.set_xlabel('Neighbourhood Group')
# Out:
# Text(0.5, 0, 'Neighbourhood Group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Seaborn ploting alwasy give you hassel free visulization just some simple coding you get what you are imaghing as i didnt select colors but it already showing the patter of colors which is preety cool

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As Observed we can see that the most expensive neighbourhood gorup is Manhatten more then 200 average price as compare to other neighbour groups

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * It will surly give the clear purspective to us that is the price making trouble or not , shall we decrease the price or increase the price.
#
# * so form the earlier graphs it is preety clear that the manhatten and brooklyn are par from the others and even in prices they still are par from the other neighbourhood groups
#
# * thats means price is not hassel here

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# **4. Most Listing in Each Room**

# %% [markdown]
# *  **Using Seaborn Countplot**

# %%
# Chart - 5 visualization code

plot_5 = sns.countplot(x=df['room_type'],hue=df['neighbourhood_group'])
plot_5.set_title('Most Listing for Each Room')
# Out:
# Text(0.5, 1.0, 'Most Listing for Each Room')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Becasue we need to sum up the more parameters as we can see in the graph , rooms and its type then count and rooms corresponding neighbourhood so it will give count flexibility to tie all

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As we seen in Graph Most listings is for Private room and Entire home/apt.
# * Majority is for Manhatten and Brooklyn, Where Manhatten is more then 13000 listing in Entire home/apt and more then 7000 in Private room. And for Brooklyn more then 9000 for Entire home and more then 10000 for Private room
# * And very less for shared rooms for every neighbourhood_group

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * We can see that the shared room is neglegible as compare to the other rooms and appartment and private rooms, thats means we have to be more focused on the private rooms and the entire house.
#
# * as observed it looks like privacy is bit a concern for people here

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# **5. Most Listed Neighbourhood (Area of Location in NYC)**

# %% [markdown]
# * **Using Seaborn Countplot**

# %%
# Chart - 6 visualization code

plt_6 =sns.countplot(x=df['neighbourhood'],order=df['neighbourhood'].value_counts().iloc[:10].index,hue=df['neighbourhood_group'])
plt_6.set_title('Most Listed Neighbourhood')
plt_6.set_xlabel('Neighbourhood')
plt_6.set_ylabel('Total Number of Counts')
plt_6.set_xticklabels(plt_6.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Williamsburg'),
#  Text(0, 0, 'Bedford-Stuyvesant'),
#  Text(0, 0, 'Harlem'),
#  Text(0, 0, 'Bushwick'),
#  Text(0, 0, 'Upper West Side'),
#  Text(0, 0, "Hell's Kitchen"),
#  Text(0, 0, 'East Village'),
#  Text(0, 0, 'Upper East Side'),
#  Text(0, 0, 'Crown Heights'),
#  Text(0, 0, 'Midtown')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Seaborn Countplot her in our case as we have to denotes certain high pitch value of diferent parameters so it gives clear and closer picture .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As we see that most listed neighbourhood interms of neighbourhood groups with its count it gives us preety clear things that the which ever things comes under the shade of manhatten and brooklyn are higher and as we see.
#
# * manhatten adn brooklyn corresponding areas williamsburg and belford ,harlem,bhushwick is hinger in listings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# * Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# **6. How Price is correspond to minimum nights**

# %%
# Chart - 7 visualization code

# price vs minimum_nights
minimum_nights_var='minimum_nights'
data=pd.concat([df['price'],df[minimum_nights_var]],axis=1)
data.plot.scatter(x=minimum_nights_var,y='price',ylim=(0,12000))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * scatters plots gives the smallest element in a broder picture which helps us to fidn the correct corelations

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As we can see that the minimum nights are cheaper if we get for year it kind of discount stuff which usualy owners do to attract to people
#
# * as usualy very less peole who pay for a year so its less showing in graph too
#
# * the soo high density is shown around 100 nights which usualy people pay for.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * as the growth which can be profitable the range is in between them so its normal , we can invite more peole according to cheaper rates of minimum nights

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# **7. Number of Reviews**

# %% [markdown]
# * **Using Seaborn Histplot**

# %%
# Chart - 8 visualization code

sns.histplot(y=df['price'],x=df['number_of_reviews'],color='green')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * for smaller values seaborn histplot is match it with very well to get insight information by little shades.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As we can see that the lesser the reviews on lesser the price which indicates the human sicology that if the price is less we need to complaint rearding servies or facility as compare to the higher price rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * it works as feedback thing for a owner who can see the insights of thier providing services. which is beneficial for the property owners

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# **7. Most Densed Places According to Latitude and Longitude**

# %% [markdown]
# **Using Scatter Plot**

# %%
# Chart - 9 visualization code

# we using Scatter plot which gives four parameters at once density latitiude ,longitude and neighbourhood
# Reference : https://seaborn.pydata.org/generated/seaborn.scatterplot.html
plt.figure(figsize = (10,6))
plot_7 = sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group)
plot_7.set_title('Densitity of Rooms')
plot_7.set_ylabel('Latitude')
plot_7.set_xlabel('Longitude')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * As for the density scater plot are preety nicely setup to show case the each and everything with its parameters and values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Latitude and Longitude visulaization provides us that Brooklyn, Manhatten and Queens are most densed with hotels and room and appartments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it is gives a very fruitful information that the location is very crucial for hotels and appartment and rooms, where people can visit frequently and easily without hassel of long distances.

# %% [markdown]
# ##### **Chart - 10**
# ##### **Chart - 11**
# ##### **Chart - 12**
# ##### **Chart - 13**
#
# ##### **was extra for my project thats why it deleted**

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

heatmap = sns.heatmap(df[dist_col_list_o].corr(), linewidths=0, vmin=-1, annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * correlation Heatmap visualization gives two parametrs correlation at certain point what other parameters are at that point ,which is we require at this point.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * we can see the set of parameters value with other parametrs as we can see that price correlation with other parametrs or reviews_per_month or calculatted _host wit the price te variation the values gives us certain point of understand what is going on that perticular point.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * The pair plot is a data visualization that plots pair-wise relationships between all the variables of a our data. This allows us to better understand the relationships visually

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * pair plot it gives the the corresponding relation between its values to the related parameter,pairing of parameter of certain different individual gives us better understand the service.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# As we gone through the entire project we encounter some key problem in it.
#
#
# *   The highest listing is only some locations ,in our case only Manhatten and Brookly and some is for Queens but the other locations as negligibel listings
#
# *   To get overcome with this problem the analysis we have is that the facility comes with the prices and services, if we could provide the facility so no one will come to our location to saty and paying us.

# %% [markdown]
# # **Conclusion**
#
# As we have gone through in deep understand of Airbnb pattern of providing services to the socity, we encounter some of the problems that have arrived.
#
# 1. Such as where should we have to work on to provide he services where the service is not commensed
# 2. we see how  prices go up and in which area they keep high it could be cons to us so we have to look in it furture and it will keep going with different options.
#
# Thanks for Evaluation.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
